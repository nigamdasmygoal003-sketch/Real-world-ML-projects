# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %matplotlib inline

# %%
df = pd.read_csv("WineQuality.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4      5.0
# 1      9.8      5.0
# 2      9.8      5.0
# ...

# %%
df_columns = df.columns.tolist()
df_columns
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1699 entries, 0 to 1698
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1699 non-null   float64
#  1   volatile acidity      1699 non-null   float64
#  2   citric acid           1699 non-null   float64
#  3   residual sugar        1699 non-null   float64
#  4   chlorides             1699 non-null   float64
#  5   free sulfur dioxide   1699 non-null   float64
#  6   total sulfur dioxide  1699 non-null   float64
#  7   density               1699 non-null   float64
#  8   pH                    1699 non-null   float64
#  9   sulphates             1699 non-null   float64
#  10  alcohol               1699 non-null   float64
#  11  quality               1699 non-null   float64
# dtypes: float64(12)
# memory usage: 159.4 KB

# %%
def plot(data,cols):
    plot  = px.histogram(data,y =cols,x = data["quality"],title=f"Quality vs {cols}")
    plot.show()

# %%
for i in df_columns:
    plot(df,i)

# %%
inputs = df.drop("quality",axis=1)
target = df["quality"]
inputs
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          7.400000          0.700000     0.000000        1.900000   0.076000
# 1          7.800000          0.880000     0.000000        2.600000   0.098000
# 2          7.800000          0.760000     0.040000        2.300000   0.092000
# 3         11.200000          0.280000     0.560000        1.900000   0.075000
# 4          7.400000          0.700000     0.000000        1.900000   0.076000
# ...             ...               ...          ...             ...        ...
# 1694       7.801551          0.774154     0.241745        2.715859   0.079321
# 1695       7.207143          0.290908     0.590842        3.962575   0.055079
# 1696      10.100031          0.964682     0.540634        3.333877   0.115459
# 1697       5.372036          0.510212     0.078397        0.982824   0.095933
# 1698       9.277331          0.354429     0.291503        0.900000   0.059163
#
# ...

# %%
from sklearn.model_selection import train_test_split
train_input ,test_input,train_target,test_target = train_test_split(inputs,target,test_size=0.3,random_state=42)
train_input
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 846        6.400000          0.640000     0.210000        1.800000   0.081000
# 1361       8.300000          0.850000     0.140000        2.500000   0.093000
# 1609       9.696900          0.364986     0.544242        0.900000   0.115087
# 177        7.500000          0.520000     0.420000        2.300000   0.087000
# 1654       7.320836          0.429900     0.264595        1.772616   0.053916
# ...             ...               ...          ...             ...        ...
# 1130       9.100000          0.600000     0.000000        1.900000   0.058000
# 1294       8.200000          0.635000     0.100000        2.100000   0.073000
# 860        7.200000          0.620000     0.060000        2.700000   0.077000
# 1459       7.900000          0.200000     0.350000        1.700000   0.054000
# 1126       5.800000          0.290000     0.260000        1.700000   0.063000
#
# ...

# %%
input_cols = list(train_input.columns)
input_cols
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol']

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(inputs)
# Out:
# MinMaxScaler()

# %%
train_input_array = scaler.transform(train_input)
test_input_array = scaler.transform(test_input)
train_input_scaled = pd.DataFrame(
    train_input_array,
    columns=train_input.columns,
    index= train_input.index
)
test_input_scaled = pd.DataFrame(
    test_input_array,
    columns=test_input.columns,
    index= test_input.index
)
train_input_scaled
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 846        0.159292          0.356164     0.210000        0.061644   0.115192
# 1361       0.327434          0.500000     0.140000        0.109589   0.135225
# 1609       0.451053          0.167799     0.544242        0.000000   0.172099
# 177        0.256637          0.273973     0.420000        0.095890   0.125209
# 1654       0.240782          0.212260     0.264595        0.059768   0.069977
# ...             ...               ...          ...             ...        ...
# 1130       0.398230          0.328767     0.000000        0.068493   0.076795
# 1294       0.318584          0.352740     0.100000        0.082192   0.101836
# 860        0.230088          0.342466     0.060000        0.123288   0.108514
# 1459       0.292035          0.054795     0.350000        0.054795   0.070117
# 1126       0.106195          0.116438     0.260000        0.054795   0.085142
#
# ...

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(train_input_scaled,train_target)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 0.45658009, -1.5964406 , -0.1470371 ,  0.23265735, -1.14335619,
#         0.34025166, -0.8169141 , -0.48290735, -0.26410129,  1.24673637,
#         1.7301218 ])

# %%
pred = model.predict(test_input)
pred
# Out:
# array([ 1.54101808e+01, -1.88418052e+01, -2.10375797e+01,  7.52172831e+00,
#         9.51630692e+00, -4.67902972e+01,  1.68853131e+01,  1.25422167e+00,
#        -3.15528140e+01,  7.18453143e+00, -2.27422631e+01,  1.76397662e+01,
#        -1.76934877e+01,  1.74175491e+01,  1.60946558e+01,  1.38411965e+01,
#        -3.72458427e+01,  1.52291244e+01, -1.33993966e+01,  5.81571995e+00,
#         7.01112747e+00, -2.68367651e+01,  1.78009816e+01, -3.66027269e+01,
#         3.41121459e-01, -3.24944718e+01, -2.16776595e+01,  8.60188184e+00,
#         2.42584722e+01, -1.53160417e+01, -3.17733894e+01, -6.08186467e+01,
#        -1.12164574e+01, -2.72977999e+01, -1.45377996e+01,  9.74828721e+00,
#         1.85677143e+01,  1.41055019e+01,  1.64845707e+01, -6.66934895e+00,
#        -5.11817986e+01,  1.91579393e+01,  1.63124239e+00,  1.41990503e+01,
#        -9.95856744e+00,  3.16904607e+00,  2.11288474e+01,  7.01112747e+00,
# ...

# %%
from sklearn.metrics import r2_score,root_mean_squared_error,mean_absolute_error
print(f"RMSE:{root_mean_squared_error(test_target,pred)}")
print(f"MAE:{mean_absolute_error(test_target,pred)}")
print(f"R2:{r2_score(test_target,pred)}")
# Out:
# RMSE:26.025801779163576
# MAE:17.962249733902762
# R2:-1091.9839153928776

# %%
data = pd.read_csv("WineQuality.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4      5.0
# 1      9.8      5.0
# 2      9.8      5.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1699 entries, 0 to 1698
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1699 non-null   float64
#  1   volatile acidity      1699 non-null   float64
#  2   citric acid           1699 non-null   float64
#  3   residual sugar        1699 non-null   float64
#  4   chlorides             1699 non-null   float64
#  5   free sulfur dioxide   1699 non-null   float64
#  6   total sulfur dioxide  1699 non-null   float64
#  7   density               1699 non-null   float64
#  8   pH                    1699 non-null   float64
#  9   sulphates             1699 non-null   float64
#  10  alcohol               1699 non-null   float64
#  11  quality               1699 non-null   float64
# dtypes: float64(12)
# memory usage: 159.4 KB

# %%
x = data.drop(columns=["quality"])
y = data["quality"]
print(x)
print(y)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          7.400000          0.700000     0.000000        1.900000   0.076000
# 1          7.800000          0.880000     0.000000        2.600000   0.098000
# 2          7.800000          0.760000     0.040000        2.300000   0.092000
# 3         11.200000          0.280000     0.560000        1.900000   0.075000
# 4          7.400000          0.700000     0.000000        1.900000   0.076000
# ...             ...               ...          ...             ...        ...
# 1694       7.801551          0.774154     0.241745        2.715859   0.079321
# 1695       7.207143          0.290908     0.590842        3.962575   0.055079
# 1696      10.100031          0.964682     0.540634        3.333877   0.115459
# 1697       5.372036          0.510212     0.078397        0.982824   0.095933
# 1698       9.277331          0.354429     0.291503        0.900000   0.059163
#
# ...

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1359, 11)
# (340, 11)
# (1359,)
# (340,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train_final = scaler.fit_transform(x_train)
x_test_final = scaler.transform(x_test)
print(x_test_final)
# Out:
# [[ 1.76470536 -0.87703144  0.72850444 ... -1.46256306  0.84135346
#   -1.04667099]
#  [ 0.64920394 -0.70838046  0.21270281 ... -1.5938687  -0.15508687
#    0.07608929]
#  [ 0.06209793  1.23110585 -0.81890044 ... -0.80603485  0.95858174
#   -0.76598092]
#  ...
#  [ 1.35373115 -0.25864451  1.91484818 ... -0.34646511  0.02075554
#    1.19884957]
#  [-0.99469288  0.30352544 -1.2831219  ...  0.44136874  0.02075554
#    2.04091978]
#  [ 0.12080853 -0.37107849  0.21270281 ...  0.11310464 -0.6826141
#   -0.57885421]]

# %%
from sklearn.linear_model import (
    LinearRegression,Ridge,Lasso,ElasticNet,
    BayesianRidge,ARDRegression,SGDRegressor,
    PassiveAggressiveRegressor,HuberRegressor,
    RANSACRegressor,TheilSenRegressor
)
from sklearn.metrics import r2_score,root_mean_squared_error

models = {
    "LinearRegression": LinearRegression(),
    "Ridge": Ridge(),
    "Lasso": Lasso(),
    "ElasticNet": ElasticNet(),
    "BayesianRidge": BayesianRidge(),
    "ARDRegression": ARDRegression(),
    "SGDRegressor": SGDRegressor(max_iter=1000),
    "PassiveAggressive": PassiveAggressiveRegressor(max_iter=1000),
    "Huber": HuberRegressor(),
    "RANSAC": RANSACRegressor(),
    "TheilSen": TheilSenRegressor()
}

results = []

for name,model in models.items():
    
    try:
        model.fit(x_train_final,y_train)
        y_pred = model.predict(x_test_final)
    
        r2 = r2_score(y_test,y_pred)
        rmse = root_mean_squared_error(y_test,y_pred)
    
        results.append((name,r2,rmse))
    except Exception as e:
        print(f"{name} failed :{e}")

results_df = pd.DataFrame(results,columns=["Model","r2-score","RMSE"])
results_df = results_df.sort_values(by="RMSE",ascending=False)

results_df
# Out:
# c:\Users\nigam\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\deprecation.py:71: FutureWarning: Class PassiveAggressiveRegressor is deprecated; this is deprecated in version 1.8 and will be removed in 1.10. Use `SGDRegressor(loss='epsilon_insensitive', penalty=None, learning_rate='pa1', eta0 = 1.0)` instead.
#   warnings.warn(msg, category=FutureWarning)
#                 Model  r2-score      RMSE
# 7   PassiveAggressive -0.277701  0.879646
# 3          ElasticNet -0.000773  0.778504
# 2               Lasso -0.000773  0.778504
# 9              RANSAC  0.111491  0.733541
# 6        SGDRegressor  0.264649  0.667330
# 10           TheilSen  0.268561  0.665552
# 5       ARDRegression  0.271268  0.664320
# 8               Huber  0.271788  0.664082
# 0    LinearRegression  0.273990  0.663078
# 1               Ridge  0.274041  0.663054
# 4       BayesianRidge  0.275368  0.662448

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=200,max_depth=15,random_state=42,n_jobs=-1)

model.fit(x_train_final,y_train)

y_pred = model.predict(x_test_final)

r2 = r2_score(y_test,y_pred)
rmse = root_mean_squared_error(y_test,y_pred)

print(f"Random Foreste Regressor R2-Score:{r2} and RMSE:{rmse}")
# Out:
# Random Foreste Regressor R2-Score:0.4085714281415187 and RMSE:0.5984725687704453

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=200,max_depth=50,random_state=42,n_jobs=-1)

model.fit(x_train_final,y_train)

y_pred = model.predict(x_test_final)

r2 = r2_score(y_test,y_pred)
rmse = root_mean_squared_error(y_test,y_pred)

print(f"Random Foreste Regressor R2-Score:{r2} and RMSE:{rmse}")
# Out:
# Random Foreste Regressor R2-Score:0.4164750853647742 and RMSE:0.5944602233247543

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=145,max_depth=50,random_state=42,n_jobs=-1)

model.fit(x_train_final,y_train)

y_pred = model.predict(x_test_final)

r2 = r2_score(y_test,y_pred)
rmse = root_mean_squared_error(y_test,y_pred)

print(f"Random Foreste Regressor R2-Score:{r2} and RMSE:{rmse}")
# Out:
# Random Foreste Regressor R2-Score:0.4216356063413761 and RMSE:0.5918257710125432

# %% [markdown]
# ## RandomForestRegressor best prediction with
#                     (n_estimators=145,
#                     max_depth=50,
#                     random_state=42,
#                     n_jobs=-1)
